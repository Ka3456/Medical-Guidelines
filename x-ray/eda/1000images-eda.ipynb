# %% [markdown]
# # 1000imagesのEDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

path = '/Users/kaise/Desktop/job/KaiTech/medical-guideline-project/x-ray/raw_data/1000images'

df = pd.read_csv(os.path.join(path, 'labels_subset_1000.csv'))

df.head()
# Out:
#         Image Index                                     Finding Labels  \
# 0  00000013_024.png                                               Mass
# 1  00000061_012.png  Edema|Effusion|Infiltration|Pleural_Thickening...
# 2  00000103_008.png                                               Mass
# 3  00000113_001.png                  Atelectasis|Cardiomegaly|Effusion
# 4  00000143_004.png                                         No Finding
#
#    Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 0           24          13           57              M            AP
# 1           12          61           77              M            AP
# 2            8         103           60              M            PA
# 3            1         113           73              M            PA
# 4            4         143           90              M            PA
#
#    OriginalImage[Width  Height]  OriginalImagePixelSpacing[x  ...  Mass  \
# ...

# %%
# 全てのカラムを表示
pd.set_option('display.max_columns', None)
df.head()
# Out:
#         Image Index                                     Finding Labels  \
# 0  00000013_024.png                                               Mass
# 1  00000061_012.png  Edema|Effusion|Infiltration|Pleural_Thickening...
# 2  00000103_008.png                                               Mass
# 3  00000113_001.png                  Atelectasis|Cardiomegaly|Effusion
# 4  00000143_004.png                                         No Finding
#
#    Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 0           24          13           57              M            AP
# 1           12          61           77              M            AP
# 2            8         103           60              M            PA
# 3            1         113           73              M            PA
# 4            4         143           90              M            PA
#
#    OriginalImage[Width  Height]  OriginalImagePixelSpacing[x     y]  \
# ...

# %%
# View Position の分布
df['View Position'].value_counts()
# Out:
# View Position
# PA    565
# AP    435
# Name: count, dtype: int64

# %%
# Patient ID のunique数
print("Patient ID のunique数: ", len(df['Patient ID'].unique()))
# 最大何枚あるか
df['Patient ID'].value_counts().max()
# Out:
# Patient ID のunique数:  893
# np.int64(5)
